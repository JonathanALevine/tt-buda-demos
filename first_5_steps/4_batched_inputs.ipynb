# %% [markdown]
# # A Practical Guide to Improving Performance: Optimizing For Throughput

# %% [markdown]
# This notebook serves as a practical guide to demonstrate how you can tune the performance of your model on Tenstorrent hardware by increasing the batch size of inputs. It will also demonstrate the appropriate way of benchmarking models on AI hardware by separating the compilation time from the run time.
#
# The tutorial will walk through an example of running the [BERT](https://en.wikipedia.org/wiki/BERT_(language_model)) model on Tenstorrent AI accelerator hardware. The model weights will be directly downloaded from the [HuggingFace library](https://huggingface.co/docs/transformers/model_doc/bert) and executed through the PyBUDA SDK.

# %% [markdown]
# ## Guide Overview
#
# In this guide, we will talk through the steps for running the BERT model trained on the [SST2](https://nlp.stanford.edu/sentiment/index.html) dataset for the **Text Classification** task.
#
# You will learn how to vary the input batch size of the model to achieve higher throughput performance. You will also learn how to configure a benchmark framework for evaluating the model performance.

# %% [markdown]
# ## Step 1: Import libraries
#
# Make sure that you have an activate Python environment with the latest version of PyBUDA installed.
#
# We will start by first pip installing the `evaluate` library which will be used to calculate the accuracy metric.

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install evaluate==0.4.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu
# Requirement already satisfied: evaluate==0.4.0 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: xxhash in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from evaluate==0.4.0) (3.4.1)
# Requirement already satisfied: responses<0.19 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from evaluate==0.4.0) (0.18.0)
# Requirement already satisfied: dill in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from evaluate==0.4.0) (0.3.5.1)
# Requirement already satisfied: requests>=2.19.0 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from evaluate==0.4.0) (2.28.2)
# Requirement already satisfied: multiprocess in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from evaluate==0.4.0) (0.70.13)
# Requirement already satisfied: pandas in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from evaluate==0.4.0) (1.5.3)
# Requirement already satisfied: tqdm>=4.62.1 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from evaluate==0.4.0) (4.66.2)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from evaluate==0.4.0) (2024.2.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from evaluate==0.4.0) (0.21.4)
# Requirement already satisfied: datasets>=2.0.0 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from evaluate==0.4.0) (2.3.2)
# Requirement already satisfied: numpy>=1.17 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from evaluate==0.4.0) (1.23.1)
# Requirement already satisfied: packaging in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from evaluate==0.4.0) (23.2)
# Requirement already satisfied: urllib3>=1.25.10 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from responses<0.19->evaluate==0.4.0) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from requests>=2.19.0->evaluate==0.4.0) (2024.2.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from requests>=2.19.0->evaluate==0.4.0) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from requests>=2.19.0->evaluate==0.4.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from pandas->evaluate==0.4.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from pandas->evaluate==0.4.0) (2024.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http" in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from fsspec[http]>=2021.05.0->evaluate==0.4.0) (3.9.3)
# Requirement already satisfied: filelock in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from huggingface-hub>=0.7.0->evaluate==0.4.0) (3.13.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from huggingface-hub>=0.7.0->evaluate==0.4.0) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from huggingface-hub>=0.7.0->evaluate==0.4.0) (4.10.0)
# Requirement already satisfied: pyarrow>=6.0.0 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from datasets>=2.0.0->evaluate==0.4.0) (15.0.0)
# Requirement already satisfied: six>=1.5 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->evaluate==0.4.0) (1.16.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http"->fsspec[http]>=2021.05.0->evaluate==0.4.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0; python_version < "3.11" in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http"->fsspec[http]>=2021.05.0->evaluate==0.4.0) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http"->fsspec[http]>=2021.05.0->evaluate==0.4.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http"->fsspec[http]>=2021.05.0->evaluate==0.4.0) (6.0.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http"->fsspec[http]>=2021.05.0->evaluate==0.4.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1; extra == "http"->fsspec[http]>=2021.05.0->evaluate==0.4.0) (23.2.0)

# %%
# import the pybuda library and additional libraries required for this tutorial
import time
from typing import Any, Dict, List, Tuple

import evaluate
import pybuda
import torch
from datasets import load_dataset
from torch.utils.data import DataLoader, Dataset
from transformers import BertForSequenceClassification, BertTokenizer

# %% [markdown]
# ## Step 2: Create helper classes and functions
#
# We will create some helper classes and functions to improve code reusability throughout this tutorial.
#
# * `SST2Dataset` -- Python Class to hold a preprocessed version of the SST2 dataset used for evaluation
# * `eval_fn` -- function to compute the evaluation score

# %%
# Create a Dataset Class to preprocess the data
class SST2Dataset(Dataset):
    """Configurable SST-2 Dataset."""

    def __init__(self, dataset: Any, tokenizer: Any, split: str, seq_len: int):
        """
        Init and preprocess SST-2 dataset.

        Parameters
        ----------
        dataset : Any
            SST-2 dataset
        tokenizer : Any
            tokenizer object from HuggingFace
        split : str
            Which split to use i.e. ["train", "validation", "test"]
        seq_len : int
            Sequence length
        """
        self.sst2 = dataset[split]
        self.data = [
            (
                tokenizer(
                    item["sentence"],
                    return_tensors="pt",
                    max_length=seq_len,
                    padding="max_length",
                    return_token_type_ids=False,
                    truncation=True,
                ),
                item["label"],
            )
            for item in self.sst2
        ]

        for data in self.data:
            tokenized = data[0]
            for item in tokenized:
                tokenized[item] = tokenized[item].squeeze()

    def __len__(self) -> int:
        """
        Return length of dataset.

        Returns
        -------
        int
            Length of dataset
        """
        return len(self.data)

    def __getitem__(self, index: int) -> Tuple[Dict[str, torch.Tensor], int]:
        """
        Return sample from dataset.

        Parameters
        ----------
        index : int
            Index of sample

        Returns
        -------
        Tuple
            Data sample in format of X, y
        """
        X, y = self.data[index]
        return X, y

# %%
# Define evaluation function
def eval_fn(outputs: List[torch.tensor], labels: List[int], metric_type: str) -> float:
    """
    Evaluation function for measuring model accuracy.

    Parameters
    ----------
    outputs : List[torch.tensor]
        Predicted outputs from model
    labels : List[int]
        List of true labels
    metric_type : str
        Type of metric to return i.e. accuracy, recall, precision, etc.

    Returns
    -------
    float
        Evaluation score.
    """

    # set evaluation metric for dataset
    accuracy_metric = evaluate.load(metric_type)

    # initialize lists to store predictions and labels
    pred_labels = []
    true_labels = []

    # store all predictions
    for output in outputs:
        pred_labels.extend(torch.argmax(output, axis=-1))

    # store all labels
    for label in labels:
        true_labels.extend(label)

    # compute the accuracy
    eval_score = accuracy_metric.compute(references=true_labels, predictions=pred_labels)

    return eval_score[metric_type]

# %% [markdown]
# ## Step 3: Download the model weights from HuggingFace

# %%
# Load BERT tokenizer and model from HuggingFace for text classification task
model_ckpt = "textattack/bert-base-uncased-SST-2"
tokenizer = BertTokenizer.from_pretrained(model_ckpt)
model = BertForSequenceClassification.from_pretrained(model_ckpt)

# %% [markdown]
# ## Step 4: Set optimal configurations
#
# For every model, you can adjust TT-BUDA configuration parameters to achieve optimized performance. Some key parameters include:
#
# * Data format e.g. BFP8, FP16_b, FP16, etc.
# * Math fidelity
# * Balancer policy
# * etc...
#
# For a full list of tuneable parameters, please refer to the TT-BUDA documentation: <https://docs.tenstorrent.com/tenstorrent/>

# %%
# Set optimal configurations
compiler_cfg = pybuda.config._get_global_compiler_config()
compiler_cfg.default_df_override = pybuda._C.DataFormat.Float16_b
compiler_cfg.enable_auto_transposing_placement = True
compiler_cfg.balancer_policy = "Ribbon"

# %% [markdown]
# ## Step 5: Instantiate Tenstorrent device
#
# The first time we use PyBUDA, we must initialize a `TTDevice` object which serves as the abstraction over the target hardware.

# %%
tt0 = pybuda.TTDevice(
    name="tt_device_0",  # here we can give our device any name we wish, for tracking purposes
    arch=pybuda.BackendDevice.Grayskull  # we set the target device architecture to compile for
)

# %% [markdown]
# ## Step 6: Create a PyBUDA module from PyTorch model
#
# Next, we must abstract the PyTorch model loaded from HuggingFace into a `pybuda.PyTorchModule` object. This will let the BUDA compiler know which model architecture and AI framework it has to compile.
#
# We then "place" this module onto the previously initialized `TTDevice`.

# %%
# Create module
pybuda_module = pybuda.PyTorchModule(
    name = "pt_bert_text_classification",  # give the module a name, this will be used for tracking purposes
    module=model  # specify the model that is being targeted for compilation
)

# Place module on device
tt0.place_module(module=pybuda_module)

# %% [markdown]
# ## Step 7: Load the SST2 dataset for evaluation

# %%
dataset = SST2Dataset(dataset=load_dataset("glue", "sst2"), tokenizer=tokenizer, split="validation", seq_len=128)
# Out:
# Downloading builder script: 28.8kB [00:00, 20.8MB/s]
# Downloading metadata: 28.7kB [00:00, 5.09MB/s]
# Downloading and preparing dataset glue/sst2 (download: 7.09 MiB, generated: 4.81 MiB, post-processed: Unknown size, total: 11.90 MiB) to /home/jonathan/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad...
# Downloading data: 100%|██████████| 7.44M/7.44M [00:00<00:00, 57.2MB/s]
# Dataset glue downloaded and prepared to /home/jonathan/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.
# 100%|██████████| 3/3 [00:00<00:00, 1209.31it/s]

# %% [markdown]
# ## Step 8: Set the batch size, prep the dataset, and load a sample input

# %%
# set batch size
batch_size = 64

# prepare the dataset for specified batch size
generator = DataLoader(dataset, batch_size=batch_size, shuffle=False, drop_last=True)

# get sample input
sample_input, _ = next(iter(generator))

# %% [markdown]
# ## Step 9: Compile the model with fixed batch size

# %%
start_compilation_time = time.time()
output_q = pybuda.initialize_pipeline(training=False, sample_inputs=list(sample_input.values()))
end_compilation_time = time.time()
# Out:
# 2024-03-06 14:39:21.007 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:39:21.008 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:39:21.005 | INFO     | Always          - initialize_child_process called on pid 577263
# /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages/flax/struct.py:132: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(data_clz, keypaths)
# /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages/flax/struct.py:132: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(data_clz, keypaths)
# /home/jonathan/Desktop/tenstorrent/tt-buda-demos/venv/lib/python3.8/site-packages/tvm/driver/build_module.py:267: UserWarning: target_host parameter is going to be deprecated. Please pass in tvm.target.Target(target, host=target_host) instead.
#   warnings.warn(
# 2024-03-06 14:39:34.047 | INFO     | tvm.relay.op.contrib.buda.buda:visit_call:817 - Adding: embedding to fallback
# 2024-03-06 14:39:34.048 | INFO     | tvm.relay.op.contrib.buda.buda:visit_call:817 - Adding: embedding to fallback
# 2024-03-06 14:39:34.051 | INFO     | tvm.relay.op.contrib.buda.buda:visit_call:817 - Adding: embedding to fallback
# 2024-03-06 14:39:37.610 | INFO     | tvm.relay.op.contrib.buda.buda:_cpu_eval:562 - cast will be executed on CPU
# 2024-03-06 14:39:37.611 | INFO     | tvm.relay.op.contrib.buda.buda:_cpu_eval:562 - strided_slice will be executed on CPU
# 2024-03-06 14:39:37.612 | INFO     | tvm.relay.op.contrib.buda.buda:_cpu_eval:562 - broadcast_to will be executed on CPU
# 2024-03-06 14:39:37.612 | INFO     | tvm.relay.op.contrib.buda.buda:_cpu_eval:562 - cast will be executed on CPU
# 2024-03-06 14:39:37.613 | INFO     | tvm.relay.op.contrib.buda.buda:_cpu_eval:562 - add will be executed on CPU
# 2024-03-06 14:39:37.614 | INFO     | tvm.relay.op.contrib.buda.buda:_cpu_eval:562 - strided_slice will be executed on CPU
# 2024-03-06 14:39:37.614 | INFO     | tvm.relay.op.contrib.buda.buda:_cpu_eval:562 - cast will be executed on CPU
# 2024-03-06 14:39:37.615 | INFO     | tvm.relay.op.contrib.buda.buda:_cpu_eval:562 - add will be executed on CPU
# 2024-03-06 14:39:38.295 | INFO     | tvm.relay.op.contrib.buda.buda:partition_for_buda:2015 - A CPU pre-process device has been created
# 2024-03-06 14:39:40.530 | DEBUG    | pybuda.tvm_to_python:_determine_node_dtype:1662 - Node 'const_06' does not have a framework dtype specified. Using TVM generated dtype.
# 2024-03-06 14:39:40.530 | DEBUG    | pybuda.tvm_to_python:_determine_node_dtype:1662 - Node 'const_16' does not have a framework dtype specified. Using TVM generated dtype.
# 2024-03-06 14:39:40.531 | DEBUG    | pybuda.tvm_to_python:_determine_node_dtype:1662 - Node 'const_26' does not have a framework dtype specified. Using TVM generated dtype.
# 2024-03-06 14:39:40.532 | DEBUG    | pybuda.tvm_to_python:_determine_node_dtype:1662 - Node 'const_36' does not have a framework dtype specified. Using TVM generated dtype.
# 2024-03-06 14:39:40.533 | DEBUG    | pybuda.tvm_to_python:_determine_node_dtype:1662 - Node 'const_46' does not have a framework dtype specified. Using TVM generated dtype.
# 2024-03-06 14:39:40.534 | DEBUG    | pybuda.tvm_to_python:_determine_node_dtype:1662 - Node 'const_56' does not have a framework dtype specified. Using TVM generated dtype.
# 2024-03-06 14:39:40.535 | DEBUG    | pybuda.tvm_to_python:_determine_node_dtype:1662 - Node 'const_66' does not have a framework dtype specified. Using TVM generated dtype.
# 2024-03-06 14:39:40.536 | DEBUG    | pybuda.tvm_to_python:_determine_node_dtype:1662 - Node 'const_76' does not have a framework dtype specified. Using TVM generated dtype.
# 2024-03-06 14:39:40.537 | DEBUG    | pybuda.tvm_to_python:_determine_node_dtype:1662 - Node 'const_86' does not have a framework dtype specified. Using TVM generated dtype.
# 2024-03-06 14:39:40.538 | DEBUG    | pybuda.tvm_to_python:_determine_node_dtype:1662 - Node 'const_96' does not have a framework dtype specified. Using TVM generated dtype.
# 2024-03-06 14:39:40.539 | DEBUG    | pybuda.tvm_to_python:_determine_node_dtype:1662 - Node 'const_106' does not have a framework dtype specified. Using TVM generated dtype.
# 2024-03-06 14:39:40.540 | DEBUG    | pybuda.tvm_to_python:_determine_node_dtype:1662 - Node 'const_116' does not have a framework dtype specified. Using TVM generated dtype.
# 2024-03-06 14:39:40.541 | DEBUG    | pybuda.tvm_to_python:_determine_node_dtype:1662 - Node 'const_126' does not have a framework dtype specified. Using TVM generated dtype.
# 2024-03-06 14:39:40.542 | DEBUG    | pybuda.tvm_to_python:_determine_node_dtype:1662 - Node 'const_136' does not have a framework dtype specified. Using TVM generated dtype.
# 2024-03-06 14:39:40.612 | WARNING  | generated_modules.pt_bert_text_classification_tt_1:process_framework_parameters:904 - bert.embeddings.word_embeddings.weight not found in self._parameters and self._constants
# 2024-03-06 14:39:40.613 | WARNING  | generated_modules.pt_bert_text_classification_tt_1:process_framework_parameters:904 - bert.embeddings.position_embeddings.weight not found in self._parameters and self._constants
# 2024-03-06 14:39:40.614 | WARNING  | generated_modules.pt_bert_text_classification_tt_1:process_framework_parameters:904 - bert.embeddings.token_type_embeddings.weight not found in self._parameters and self._constants
# 2024-03-06 14:39:40.681 | WARNING  | generated_modules.pt_bert_text_classification_tt_1:process_framework_parameters:904 - bert.embeddings.position_ids not found in self._parameters and self._constants
# 2024-03-06 14:39:40.682 | WARNING  | generated_modules.pt_bert_text_classification_tt_1:process_framework_parameters:904 - bert.embeddings.token_type_ids not found in self._parameters and self._constants
# 2024-03-06 14:39:40.684 | WARNING  | pybuda.run.impl:_translate_framework_modules_on_devices:163 - Unsupported ops found before main graph, will be executed on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:39:40.685 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:39:40.798 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:39:40.798 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:39:40.799 | DEBUG    | pybuda.cpudevice:_create_forward_device_connector:1039 - Creating forward device connector from CPUDevice 'cpu0_fallback' to TTDevice 'tt_device_0'
# 2024-03-06 14:39:40.799 | DEBUG    | pybuda.cpudevice:_create_input_queue_device_connector:1073 - Creating input queue connector on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:39:40.800 | DEBUG    | pybuda.ttdevice:_create_intermediates_queue_device_connector:1371 - Creating fwd intermediates queue connector on TTDevice 'tt_device_0'
# 2024-03-06 14:39:40.800 | DEBUG    | pybuda.ttdevice:_create_forward_output_queue_device_connector:1351 - Creating forward output queue connector on TTDevice 'tt_device_0'
# 2024-03-06 14:39:41.028 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:39:41.031 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:39:41.032 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:39:41.032 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:39:45.525 | INFO     | pybuda.device_connector:pusher_thread_main:144 - Pusher thread on <pybuda.device_connector.DirectPusherDeviceConnector object at 0x7f1d1c9e1520> starting
# 2024-03-06 14:39:45.526 | DEBUG    | pybuda.device:run_next_command:452 - Received COMPILE command on CPUDevice 'cpu0_fallback' / 579546
# 2024-03-06 14:39:45.665 | INFO     | pybuda.device_connector:pusher_thread_main:144 - Pusher thread on <pybuda.device_connector.DirectPusherDeviceConnector object at 0x7f13e88ee0d0> starting
# 2024-03-06 14:39:45.666 | DEBUG    | pybuda.device:run_next_command:452 - Received COMPILE command on TTDevice 'tt_device_0' / 579556
# 2024-03-06 14:39:45.666 | DEBUG    | pybuda.ttdevice:compile_for:770 - Compiling for Inference mode on TTDevice 'tt_device_0'
# 2024-03-06 14:39:45.666 | INFO     | pybuda.ci:initialize_output_build_directory:94 - Pybuda output build directory for compiled artifacts: /tmp/jonathan/8148d80c3efc
# 2024-03-06 14:39:45.667 | INFO     | pybuda.ci:create_symlink:85 - Symlink created from /home/jonathan/Desktop/tenstorrent/tt-buda-demos/first_5_steps/tt_build/test_out to /tmp/jonathan/8148d80c3efc
# 2024-03-06 14:39:45.525 | INFO     | Always          - initialize_child_process called on pid 579546
# 2024-03-06 14:39:45.665 | INFO     | Always          - initialize_child_process called on pid 579556
# 2024-03-06 14:39:45.681 | INFO     | SiliconDriver   - Detected 1 PCI device
# 2024-03-06 14:39:45.687 | INFO     | SiliconDriver   - Using 1 Hugepages/NumHostMemChannels for TTDevice (pci_interface_id: 0 device_id: 0xfaca revision: 0)
# 2024-03-06 14:39:45.731 | INFO     | pybuda.compile:pybuda_compile:220 - Device grid size: r = 10, c = 12
# 2024-03-06 14:39:45.732 | INFO     | pybuda.compile:pybuda_compile:230 - Using chips: [0]
# 2024-03-06 14:39:45.732 | INFO     | pybuda.compile:pybuda_compile:246 - Generating initial graph
# 2024-03-06 14:39:45.992 | INFO     | pybuda.compile:pybuda_compile:319 - Running post initial graph pass
# 2024-03-06 14:39:46.394 | INFO     | pybuda.compile:pybuda_compile:391 - Running post autograd graph pass
# 2024-03-06 14:39:46.571 | INFO     | pybuda.compile:pybuda_compile:424 - Lowering to Buda
# 2024-03-06 14:39:46.710 | INFO     | GraphCompiler   - Running with Automatic Mixed Precision Level = 0.
# 2024-03-06 14:39:46.766 | INFO     | Always          - Running Balancer with Policy: PolicyType::Ribbon
# 2024-03-06 14:39:47.510 | INFO     | Always          - Running Balancer with Policy: PolicyType::Ribbon
# 2024-03-06 14:39:48.831 | INFO     | Balancer        - Starting Ribbon balancing.
# 2024-03-06 14:39:49.117 | INFO     | Balancer        - Balancing 1% complete.
# 2024-03-06 14:39:49.366 | INFO     | Balancer        - Balancing 4% complete.
# 2024-03-06 14:39:49.713 | INFO     | Balancer        - Balancing 19% complete.
# 2024-03-06 14:39:50.099 | INFO     | Balancer        - Balancing 33% complete.
# 2024-03-06 14:39:50.431 | INFO     | Balancer        - Balancing 43% complete.
# 2024-03-06 14:39:51.015 | INFO     | Balancer        - Balancing 54% complete.
# 2024-03-06 14:39:51.312 | INFO     | Balancer        - Balancing 64% complete.
# 2024-03-06 14:39:51.842 | INFO     | Balancer        - Balancing 73% complete.
# 2024-03-06 14:39:52.324 | INFO     | Balancer        - Balancing 81% complete.
# 2024-03-06 14:39:52.602 | INFO     | Balancer        - Balancing 89% complete.
# 2024-03-06 14:39:53.025 | INFO     | Balancer        - Balancing 96% complete.
# 2024-03-06 14:39:53.098 | INFO     | Balancer        - Balancing 100% completed!
# 2024-03-06 14:39:53.237 | WARNING  | Placer          - Compilation Option with input queue placed on host, but Grayskull does not support fast device reads from host. Placer opting to allocate the queue on device instead.
# 2024-03-06 14:39:53.242 | INFO     | Always          - Lookup contexts -- arch:system scope:device0 name:harvesting_mask
# 2024-03-06 14:39:53.255 | INFO     | SiliconDriver   - Detected 1 PCI device
# 2024-03-06 14:39:53.256 | INFO     | SiliconDriver   - Using 1 Hugepages/NumHostMemChannels for TTDevice (pci_interface_id: 0 device_id: 0xfaca revision: 0)
# 2024-03-06 14:39:53.305 | INFO     | Runtime         - Cluster descriptor file does not exist at path=
| DEBUG    | pybuda.backend:push_constants_and_parameters:446 - Pushing to parameter bert.encoder.layer.11.attention.output.dense.bias
# 2024-03-06 14:40:35.006 | DEBUG    | pybuda.backend:push_constants_and_parameters:446 - Pushing to parameter bert.encoder.layer.11.attention.output.LayerNorm.weight
# 2024-03-06 14:40:35.006 | DEBUG    | pybuda.backend:push_constants_and_parameters:446 - Pushing to parameter bert.encoder.layer.11.attention.output.LayerNorm.bias
# 2024-03-06 14:40:35.006 | DEBUG    | pybuda.backend:push_constants_and_parameters:446 - Pushing to parameter bert.encoder.layer.11.intermediate.dense.weight
# 2024-03-06 14:40:35.009 | DEBUG    | pybuda.backend:push_constants_and_parameters:446 - Pushing to parameter bert.encoder.layer.11.intermediate.dense.bias
# 2024-03-06 14:40:35.009 | DEBUG    | pybuda.backend:push_constants_and_parameters:446 - Pushing to parameter bert.encoder.layer.11.output.dense.weight
# 2024-03-06 14:40:35.012 | DEBUG    | pybuda.backend:push_constants_and_parameters:446 - Pushing to parameter bert.encoder.layer.11.output.dense.bias
# 2024-03-06 14:40:35.012 | DEBUG    | pybuda.backend:push_constants_and_parameters:446 - Pushing to parameter bert.encoder.layer.11.output.LayerNorm.weight
# 2024-03-06 14:40:35.013 | DEBUG    | pybuda.backend:push_constants_and_parameters:446 - Pushing to parameter bert.encoder.layer.11.output.LayerNorm.bias
# 2024-03-06 14:40:35.013 | DEBUG    | pybuda.backend:push_constants_and_parameters:446 - Pushing to parameter bert.pooler.dense.weight
# 2024-03-06 14:40:35.013 | DEBUG    | pybuda.backend:push_constants_and_parameters:446 - Pushing to parameter bert.pooler.dense.bias
# 2024-03-06 14:40:35.014 | DEBUG    | pybuda.backend:push_constants_and_parameters:446 - Pushing to parameter classifier.weight
# 2024-03-06 14:40:35.014 | DEBUG    | pybuda.backend:push_constants_and_parameters:446 - Pushing to parameter classifier.bias
# 2024-03-06 14:40:35.016 | INFO     | Netlist         - Parsing Netlist from file: /tmp/jonathan/8148d80c3efc/pt_bert_text_classification_tt_1_netlist.yaml
# 2024-03-06 14:40:35.206 | INFO     | SiliconDriver   - Detected 1 PCI device
# 2024-03-06 14:40:35.229 | INFO     | SiliconDriver   - Using 1 Hugepages/NumHostMemChannels for TTDevice (pci_interface_id: 0 device_id: 0xfaca revision: 0)
# 2024-03-06 14:40:35.250 | INFO     | SiliconDriver   - Disable PCIE DMA
# 2024-03-06 14:40:35.251 | INFO     | Netlist         - Parsing Netlist from file: /tmp/jonathan/8148d80c3efc/pt_bert_text_classification_tt_1_netlist.yaml

# %% [markdown]
# ## Step 10: Run benchmark on SST2 dataset with `batch_size==64`

# %%
# Run benchmark loop
store_outputs = []
store_labels = []
start_runtime_time = time.time()
for batch, labels in generator:
    # push input to Tenstorrent device
    tt0.push_to_inputs(batch)

    # run inference on Tenstorrent device
    pybuda.run_forward(input_count=1)
    output = output_q.get()  # inference will return a queue object, get last returned object

    # store outputs
    store_labels.append(labels)
    store_outputs.append(output[0].value())
end_runtime_time = time.time()

# Process output times
total_runtime_time = end_runtime_time - start_runtime_time
total_compilation_time = end_compilation_time - start_compilation_time
total_samples = len(generator) *  batch_size
eval_score = eval_fn(store_outputs, store_labels, "accuracy")
# Out:
# 2024-03-06 14:40:35.262 | INFO     | pybuda.device:push_to_inputs:216 - push_to_inputs redirected from TTDevice 'tt_device_0' to CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:35.263 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:35.264 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: TTDevice 'tt_device_0'
# 2024-03-06 14:40:35.266 | INFO     | Runtime         - Running program 'run_fwd_0' with params [("$p_loop_count", "1")]
# 2024-03-06 14:40:35.265 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on TTDevice 'tt_device_0' / 579556
# 2024-03-06 14:40:35.265 | DEBUG    | pybuda.ttdevice:forward:862 - Starting forward on TTDevice 'tt_device_0'
# 2024-03-06 14:40:35.266 | DEBUG    | pybuda.backend:feeder_thread_main:142 - Run feeder thread cmd: fwd
# 2024-03-06 14:40:35.266 | DEBUG    | pybuda.backend:read_queues:316 - Reading output queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:35.452 | INFO     | SiliconDriver   - Detected 1 PCI device
# 2024-03-06 14:40:35.503 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on CPUDevice 'cpu0_fallback' / 579546
# 2024-03-06 14:40:35.503 | DEBUG    | pybuda.cpudevice:forward_pt:191 - Starting forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:35.521 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:35.521 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:35.521 | DEBUG    | pybuda.cpudevice:forward_pt:265 - Ending forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:35.521 | DEBUG    | pybuda.device_connector:pusher_thread_main:159 - Pusher thread pushing tensors
# 2024-03-06 14:40:35.522 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue pybuda_6_i0
# 2024-03-06 14:40:35.528 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue attention_mask_1
# 2024-03-06 14:40:35.638 | DEBUG    | pybuda.backend:read_queues:376 - Done reading queues
# 2024-03-06 14:40:35.638 | DEBUG    | pybuda.backend:pop_queues:382 - Popping from queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:35.640 | INFO     | pybuda.device:push_to_inputs:216 - push_to_inputs redirected from TTDevice 'tt_device_0' to CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:35.640 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:35.641 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: TTDevice 'tt_device_0'
# 2024-03-06 14:40:35.483 | INFO     | SiliconDriver   - Using 1 Hugepages/NumHostMemChannels for TTDevice (pci_interface_id: 0 device_id: 0xfaca revision: 0)
# 2024-03-06 14:40:35.502 | INFO     | SiliconDriver   - Disable PCIE DMA
# 2024-03-06 14:40:35.642 | INFO     | Runtime         - Running program 'run_fwd_0' with params [("$p_loop_count", "1")]
# 2024-03-06 14:40:35.642 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on CPUDevice 'cpu0_fallback' / 579546
# 2024-03-06 14:40:35.642 | DEBUG    | pybuda.cpudevice:forward_pt:191 - Starting forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:35.642 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on TTDevice 'tt_device_0' / 579556
# 2024-03-06 14:40:35.642 | DEBUG    | pybuda.ttdevice:forward:862 - Starting forward on TTDevice 'tt_device_0'
# 2024-03-06 14:40:35.642 | DEBUG    | pybuda.backend:feeder_thread_main:142 - Run feeder thread cmd: fwd
# 2024-03-06 14:40:35.643 | DEBUG    | pybuda.backend:read_queues:316 - Reading output queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:35.656 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:35.657 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:35.657 | DEBUG    | pybuda.cpudevice:forward_pt:265 - Ending forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:35.657 | DEBUG    | pybuda.device_connector:pusher_thread_main:159 - Pusher thread pushing tensors
# 2024-03-06 14:40:35.658 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue pybuda_6_i0
# 2024-03-06 14:40:35.662 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue attention_mask_1
# 2024-03-06 14:40:35.773 | DEBUG    | pybuda.backend:read_queues:376 - Done reading queues
# 2024-03-06 14:40:35.773 | DEBUG    | pybuda.backend:pop_queues:382 - Popping from queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:35.775 | INFO     | pybuda.device:push_to_inputs:216 - push_to_inputs redirected from TTDevice 'tt_device_0' to CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:35.775 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:35.776 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: TTDevice 'tt_device_0'
# 2024-03-06 14:40:35.776 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on CPUDevice 'cpu0_fallback' / 579546
# 2024-03-06 14:40:35.776 | DEBUG    | pybuda.cpudevice:forward_pt:191 - Starting forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:35.777 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on TTDevice 'tt_device_0' / 579556
# 2024-03-06 14:40:35.778 | DEBUG    | pybuda.ttdevice:forward:862 - Starting forward on TTDevice 'tt_device_0'
# 2024-03-06 14:40:35.778 | DEBUG    | pybuda.backend:read_queues:316 - Reading output queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:35.778 | DEBUG    | pybuda.backend:feeder_thread_main:142 - Run feeder thread cmd: fwd
# 2024-03-06 14:40:35.787 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:35.787 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:35.787 | DEBUG    | pybuda.cpudevice:forward_pt:265 - Ending forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:35.788 | DEBUG    | pybuda.device_connector:pusher_thread_main:159 - Pusher thread pushing tensors
# 2024-03-06 14:40:35.788 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue pybuda_6_i0
# 2024-03-06 14:40:35.792 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue attention_mask_1
# 2024-03-06 14:40:35.903 | DEBUG    | pybuda.backend:read_queues:376 - Done reading queues
# 2024-03-06 14:40:35.903 | DEBUG    | pybuda.backend:pop_queues:382 - Popping from queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:35.905 | INFO     | pybuda.device:push_to_inputs:216 - push_to_inputs redirected from TTDevice 'tt_device_0' to CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:35.905 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:35.906 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: TTDevice 'tt_device_0'
# 2024-03-06 14:40:35.907 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on CPUDevice 'cpu0_fallback' / 579546
# 2024-03-06 14:40:35.907 | DEBUG    | pybuda.cpudevice:forward_pt:191 - Starting forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:35.907 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on TTDevice 'tt_device_0' / 579556
# 2024-03-06 14:40:35.907 | DEBUG    | pybuda.ttdevice:forward:862 - Starting forward on TTDevice 'tt_device_0'
# 2024-03-06 14:40:35.907 | DEBUG    | pybuda.backend:feeder_thread_main:142 - Run feeder thread cmd: fwd
# 2024-03-06 14:40:35.908 | DEBUG    | pybuda.backend:read_queues:316 - Reading output queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:35.917 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:35.917 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:35.917 | DEBUG    | pybuda.cpudevice:forward_pt:265 - Ending forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:35.918 | DEBUG    | pybuda.device_connector:pusher_thread_main:159 - Pusher thread pushing tensors
# 2024-03-06 14:40:35.918 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue pybuda_6_i0
# 2024-03-06 14:40:35.922 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue attention_mask_1
# 2024-03-06 14:40:35.778 | INFO     | Runtime         - Running program 'run_fwd_0' with params [("$p_loop_count", "1")]
# 2024-03-06 14:40:35.907 | INFO     | Runtime         - Running program 'run_fwd_0' with params [("$p_loop_count", "1")]
# 2024-03-06 14:40:36.033 | DEBUG    | pybuda.backend:read_queues:376 - Done reading queues
# 2024-03-06 14:40:36.034 | DEBUG    | pybuda.backend:pop_queues:382 - Popping from queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:36.035 | INFO     | pybuda.device:push_to_inputs:216 - push_to_inputs redirected from TTDevice 'tt_device_0' to CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.035 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.036 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: TTDevice 'tt_device_0'
# 2024-03-06 14:40:36.037 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on CPUDevice 'cpu0_fallback' / 579546
# 2024-03-06 14:40:36.037 | DEBUG    | pybuda.cpudevice:forward_pt:191 - Starting forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.037 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on TTDevice 'tt_device_0' / 579556
# 2024-03-06 14:40:36.037 | DEBUG    | pybuda.ttdevice:forward:862 - Starting forward on TTDevice 'tt_device_0'
# 2024-03-06 14:40:36.038 | DEBUG    | pybuda.backend:feeder_thread_main:142 - Run feeder thread cmd: fwd
# 2024-03-06 14:40:36.038 | DEBUG    | pybuda.backend:read_queues:316 - Reading output queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:36.047 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:36.048 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:36.048 | DEBUG    | pybuda.cpudevice:forward_pt:265 - Ending forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.048 | DEBUG    | pybuda.device_connector:pusher_thread_main:159 - Pusher thread pushing tensors
# 2024-03-06 14:40:36.049 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue pybuda_6_i0
# 2024-03-06 14:40:36.052 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue attention_mask_1
# 2024-03-06 14:40:36.163 | DEBUG    | pybuda.backend:read_queues:376 - Done reading queues
# 2024-03-06 14:40:36.164 | DEBUG    | pybuda.backend:pop_queues:382 - Popping from queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:36.165 | INFO     | pybuda.device:push_to_inputs:216 - push_to_inputs redirected from TTDevice 'tt_device_0' to CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.165 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.166 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: TTDevice 'tt_device_0'
# 2024-03-06 14:40:36.167 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on CPUDevice 'cpu0_fallback' / 579546
# 2024-03-06 14:40:36.167 | DEBUG    | pybuda.cpudevice:forward_pt:191 - Starting forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.167 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on TTDevice 'tt_device_0' / 579556
# 2024-03-06 14:40:36.167 | DEBUG    | pybuda.ttdevice:forward:862 - Starting forward on TTDevice 'tt_device_0'
# 2024-03-06 14:40:36.168 | DEBUG    | pybuda.backend:feeder_thread_main:142 - Run feeder thread cmd: fwd
# 2024-03-06 14:40:36.168 | DEBUG    | pybuda.backend:read_queues:316 - Reading output queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:36.176 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:36.176 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:36.176 | DEBUG    | pybuda.cpudevice:forward_pt:265 - Ending forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.176 | DEBUG    | pybuda.device_connector:pusher_thread_main:159 - Pusher thread pushing tensors
# 2024-03-06 14:40:36.177 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue pybuda_6_i0
# 2024-03-06 14:40:36.180 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue attention_mask_1
# 2024-03-06 14:40:36.038 | INFO     | Runtime         - Running program 'run_fwd_0' with params [("$p_loop_count", "1")]
# 2024-03-06 14:40:36.168 | INFO     | Runtime         - Running program 'run_fwd_0' with params [("$p_loop_count", "1")]
# 2024-03-06 14:40:36.292 | DEBUG    | pybuda.backend:read_queues:376 - Done reading queues
# 2024-03-06 14:40:36.292 | DEBUG    | pybuda.backend:pop_queues:382 - Popping from queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:36.293 | INFO     | pybuda.device:push_to_inputs:216 - push_to_inputs redirected from TTDevice 'tt_device_0' to CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.294 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.295 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: TTDevice 'tt_device_0'
# 2024-03-06 14:40:36.295 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on CPUDevice 'cpu0_fallback' / 579546
# 2024-03-06 14:40:36.295 | DEBUG    | pybuda.cpudevice:forward_pt:191 - Starting forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.297 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on TTDevice 'tt_device_0' / 579556
# 2024-03-06 14:40:36.297 | DEBUG    | pybuda.ttdevice:forward:862 - Starting forward on TTDevice 'tt_device_0'
# 2024-03-06 14:40:36.297 | DEBUG    | pybuda.backend:read_queues:316 - Reading output queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:36.297 | DEBUG    | pybuda.backend:feeder_thread_main:142 - Run feeder thread cmd: fwd
# 2024-03-06 14:40:36.304 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:36.304 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:36.304 | DEBUG    | pybuda.cpudevice:forward_pt:265 - Ending forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.305 | DEBUG    | pybuda.device_connector:pusher_thread_main:159 - Pusher thread pushing tensors
# 2024-03-06 14:40:36.305 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue pybuda_6_i0
# 2024-03-06 14:40:36.309 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue attention_mask_1
# 2024-03-06 14:40:36.420 | DEBUG    | pybuda.backend:read_queues:376 - Done reading queues
# 2024-03-06 14:40:36.420 | DEBUG    | pybuda.backend:pop_queues:382 - Popping from queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:36.421 | INFO     | pybuda.device:push_to_inputs:216 - push_to_inputs redirected from TTDevice 'tt_device_0' to CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.422 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.423 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: TTDevice 'tt_device_0'
# 2024-03-06 14:40:36.423 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on CPUDevice 'cpu0_fallback' / 579546
# 2024-03-06 14:40:36.423 | DEBUG    | pybuda.cpudevice:forward_pt:191 - Starting forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.424 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on TTDevice 'tt_device_0' / 579556
# 2024-03-06 14:40:36.424 | DEBUG    | pybuda.ttdevice:forward:862 - Starting forward on TTDevice 'tt_device_0'
# 2024-03-06 14:40:36.424 | DEBUG    | pybuda.backend:feeder_thread_main:142 - Run feeder thread cmd: fwd
# 2024-03-06 14:40:36.425 | DEBUG    | pybuda.backend:read_queues:316 - Reading output queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:36.434 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:36.434 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:36.434 | DEBUG    | pybuda.cpudevice:forward_pt:265 - Ending forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.434 | DEBUG    | pybuda.device_connector:pusher_thread_main:159 - Pusher thread pushing tensors
# 2024-03-06 14:40:36.435 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue pybuda_6_i0
# 2024-03-06 14:40:36.438 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue attention_mask_1
# 2024-03-06 14:40:36.297 | INFO     | Runtime         - Running program 'run_fwd_0' with params [("$p_loop_count", "1")]
# 2024-03-06 14:40:36.425 | INFO     | Runtime         - Running program 'run_fwd_0' with params [("$p_loop_count", "1")]
# 2024-03-06 14:40:36.549 | DEBUG    | pybuda.backend:read_queues:376 - Done reading queues
# 2024-03-06 14:40:36.550 | DEBUG    | pybuda.backend:pop_queues:382 - Popping from queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:36.551 | INFO     | pybuda.device:push_to_inputs:216 - push_to_inputs redirected from TTDevice 'tt_device_0' to CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.552 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.553 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: TTDevice 'tt_device_0'
# 2024-03-06 14:40:36.554 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on CPUDevice 'cpu0_fallback' / 579546
# 2024-03-06 14:40:36.554 | DEBUG    | pybuda.cpudevice:forward_pt:191 - Starting forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.554 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on TTDevice 'tt_device_0' / 579556
# 2024-03-06 14:40:36.555 | DEBUG    | pybuda.ttdevice:forward:862 - Starting forward on TTDevice 'tt_device_0'
# 2024-03-06 14:40:36.555 | DEBUG    | pybuda.backend:feeder_thread_main:142 - Run feeder thread cmd: fwd
# 2024-03-06 14:40:36.555 | DEBUG    | pybuda.backend:read_queues:316 - Reading output queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:36.563 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:36.563 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:36.563 | DEBUG    | pybuda.cpudevice:forward_pt:265 - Ending forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.563 | DEBUG    | pybuda.device_connector:pusher_thread_main:159 - Pusher thread pushing tensors
# 2024-03-06 14:40:36.564 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue pybuda_6_i0
# 2024-03-06 14:40:36.568 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue attention_mask_1
# 2024-03-06 14:40:36.679 | DEBUG    | pybuda.backend:read_queues:376 - Done reading queues
# 2024-03-06 14:40:36.679 | DEBUG    | pybuda.backend:pop_queues:382 - Popping from queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:36.680 | INFO     | pybuda.device:push_to_inputs:216 - push_to_inputs redirected from TTDevice 'tt_device_0' to CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.681 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.682 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: TTDevice 'tt_device_0'
# 2024-03-06 14:40:36.683 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on CPUDevice 'cpu0_fallback' / 579546
# 2024-03-06 14:40:36.683 | DEBUG    | pybuda.cpudevice:forward_pt:191 - Starting forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.683 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on TTDevice 'tt_device_0' / 579556
# 2024-03-06 14:40:36.683 | DEBUG    | pybuda.ttdevice:forward:862 - Starting forward on TTDevice 'tt_device_0'
# 2024-03-06 14:40:36.684 | DEBUG    | pybuda.backend:feeder_thread_main:142 - Run feeder thread cmd: fwd
# 2024-03-06 14:40:36.684 | DEBUG    | pybuda.backend:read_queues:316 - Reading output queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:36.693 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:36.693 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:36.693 | DEBUG    | pybuda.cpudevice:forward_pt:265 - Ending forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.694 | DEBUG    | pybuda.device_connector:pusher_thread_main:159 - Pusher thread pushing tensors
# 2024-03-06 14:40:36.694 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue pybuda_6_i0
# 2024-03-06 14:40:36.698 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue attention_mask_1
# 2024-03-06 14:40:36.555 | INFO     | Runtime         - Running program 'run_fwd_0' with params [("$p_loop_count", "1")]
# 2024-03-06 14:40:36.684 | INFO     | Runtime         - Running program 'run_fwd_0' with params [("$p_loop_count", "1")]
# 2024-03-06 14:40:36.810 | DEBUG    | pybuda.backend:read_queues:376 - Done reading queues
# 2024-03-06 14:40:36.810 | DEBUG    | pybuda.backend:pop_queues:382 - Popping from queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:36.811 | INFO     | pybuda.device:push_to_inputs:216 - push_to_inputs redirected from TTDevice 'tt_device_0' to CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.812 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.813 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: TTDevice 'tt_device_0'
# 2024-03-06 14:40:36.813 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on CPUDevice 'cpu0_fallback' / 579546
# 2024-03-06 14:40:36.813 | DEBUG    | pybuda.cpudevice:forward_pt:191 - Starting forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.814 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on TTDevice 'tt_device_0' / 579556
# 2024-03-06 14:40:36.814 | DEBUG    | pybuda.ttdevice:forward:862 - Starting forward on TTDevice 'tt_device_0'
# 2024-03-06 14:40:36.814 | DEBUG    | pybuda.backend:feeder_thread_main:142 - Run feeder thread cmd: fwd
# 2024-03-06 14:40:36.815 | DEBUG    | pybuda.backend:read_queues:316 - Reading output queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:36.824 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:36.824 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:36.824 | DEBUG    | pybuda.cpudevice:forward_pt:265 - Ending forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.824 | DEBUG    | pybuda.device_connector:pusher_thread_main:159 - Pusher thread pushing tensors
# 2024-03-06 14:40:36.825 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue pybuda_6_i0
# 2024-03-06 14:40:36.829 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue attention_mask_1
# 2024-03-06 14:40:36.940 | DEBUG    | pybuda.backend:read_queues:376 - Done reading queues
# 2024-03-06 14:40:36.941 | DEBUG    | pybuda.backend:pop_queues:382 - Popping from queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:36.942 | INFO     | pybuda.device:push_to_inputs:216 - push_to_inputs redirected from TTDevice 'tt_device_0' to CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.942 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.943 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: TTDevice 'tt_device_0'
# 2024-03-06 14:40:36.943 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on CPUDevice 'cpu0_fallback' / 579546
# 2024-03-06 14:40:36.944 | DEBUG    | pybuda.cpudevice:forward_pt:191 - Starting forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.945 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on TTDevice 'tt_device_0' / 579556
# 2024-03-06 14:40:36.945 | DEBUG    | pybuda.ttdevice:forward:862 - Starting forward on TTDevice 'tt_device_0'
# 2024-03-06 14:40:36.945 | DEBUG    | pybuda.backend:feeder_thread_main:142 - Run feeder thread cmd: fwd
# 2024-03-06 14:40:36.945 | DEBUG    | pybuda.backend:read_queues:316 - Reading output queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:36.952 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:36.952 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:36.953 | DEBUG    | pybuda.cpudevice:forward_pt:265 - Ending forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:36.953 | DEBUG    | pybuda.device_connector:pusher_thread_main:159 - Pusher thread pushing tensors
# 2024-03-06 14:40:36.953 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue pybuda_6_i0
# 2024-03-06 14:40:36.957 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue attention_mask_1
# 2024-03-06 14:40:36.814 | INFO     | Runtime         - Running program 'run_fwd_0' with params [("$p_loop_count", "1")]
# 2024-03-06 14:40:36.945 | INFO     | Runtime         - Running program 'run_fwd_0' with params [("$p_loop_count", "1")]
# 2024-03-06 14:40:37.068 | DEBUG    | pybuda.backend:read_queues:376 - Done reading queues
# 2024-03-06 14:40:37.068 | DEBUG    | pybuda.backend:pop_queues:382 - Popping from queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:37.070 | INFO     | pybuda.device:push_to_inputs:216 - push_to_inputs redirected from TTDevice 'tt_device_0' to CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:37.070 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:37.071 | DEBUG    | pybuda.run.impl:_run_forward:641 - Running concurrent device forward: TTDevice 'tt_device_0'
# 2024-03-06 14:40:37.071 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on CPUDevice 'cpu0_fallback' / 579546
# 2024-03-06 14:40:37.072 | DEBUG    | pybuda.cpudevice:forward_pt:191 - Starting forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:37.072 | DEBUG    | pybuda.device:run_next_command:426 - Received RUN_FORWARD command on TTDevice 'tt_device_0' / 579556
# 2024-03-06 14:40:37.073 | DEBUG    | pybuda.ttdevice:forward:862 - Starting forward on TTDevice 'tt_device_0'
# 2024-03-06 14:40:37.073 | DEBUG    | pybuda.backend:feeder_thread_main:142 - Run feeder thread cmd: fwd
# 2024-03-06 14:40:37.073 | DEBUG    | pybuda.backend:read_queues:316 - Reading output queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:37.082 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:37.082 | WARNING  | pybuda.tensor:pytorch_dtype_to_buda_dataformat:585 - Parameter is int64. Setting to int8 for now.
# 2024-03-06 14:40:37.082 | DEBUG    | pybuda.cpudevice:forward_pt:265 - Ending forward on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:37.082 | DEBUG    | pybuda.device_connector:pusher_thread_main:159 - Pusher thread pushing tensors
# 2024-03-06 14:40:37.083 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue pybuda_6_i0
# 2024-03-06 14:40:37.087 | DEBUG    | pybuda.backend:push_to_queues:407 - Pushing to queue attention_mask_1
# 2024-03-06 14:40:37.198 | DEBUG    | pybuda.backend:read_queues:376 - Done reading queues
# 2024-03-06 14:40:37.198 | DEBUG    | pybuda.backend:pop_queues:382 - Popping from queue pt_bert_text_classification_tt_1.output_add_651
# 2024-03-06 14:40:37.073 | INFO     | Runtime         - Running program 'run_fwd_0' with params [("$p_loop_count", "1")]
# Downloading builder script: 100%|██████████| 4.20k/4.20k [00:00<00:00, 1.13MB/s]

# %%
# Display results
print("Benchmark Result")
print(f" Model compilation time: {total_compilation_time:.3f}s")
print(f" Total runtime time for {total_samples} inputs: {total_runtime_time:.3f}s")
print(f" Throughput: {(total_samples / total_runtime_time):.1f} samples/s")
print(f" Accuracy: {(eval_score * 100):.1f}%")
# Out:
# Benchmark Result
#  Model compilation time: 74.247s
#  Total runtime time for 832 inputs: 1.939s
#  Throughput: 429.1 samples/s
#  Accuracy: 92.1%

# %% [markdown]
# ## Step 11: Shutdown PyBuda

# %%
pybuda.shutdown()
# Out:
# 2024-03-06 14:40:37.574 | DEBUG    | pybuda.run.impl:_shutdown:1262 - PyBuda shutdown
# 2024-03-06 14:40:37.575 | DEBUG    | pybuda.device:run_next_command:416 - Received SHUTDOWN command on TTDevice 'tt_device_0'
# 2024-03-06 14:40:37.575 | DEBUG    | pybuda.device:run_next_command:416 - Received SHUTDOWN command on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:37.575 | DEBUG    | pybuda.device:run_next_command:419 - Waiting for barrier on TTDevice 'tt_device_0'
# 2024-03-06 14:40:37.575 | DEBUG    | pybuda.device:run_next_command:419 - Waiting for barrier on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:37.575 | DEBUG    | pybuda.run.impl:_shutdown:1278 - Waiting until processes done
# 2024-03-06 14:40:37.575 | DEBUG    | pybuda.device:run_next_command:421 - Shutting down on TTDevice 'tt_device_0'
# 2024-03-06 14:40:37.575 | DEBUG    | pybuda.device:run_next_command:421 - Shutting down on CPUDevice 'cpu0_fallback'
# 2024-03-06 14:40:37.583 | DEBUG    | pybuda.device:atexit_handler:919 - atexit handler called for (CPUDevice 'cpu0_fallback',)
# 2024-03-06 14:40:37.583 | DEBUG    | pybuda.device:atexit_handler:923 - atexit handler completed
# 2024-03-06 14:40:37.590 | DEBUG    | pybuda.backend:feeder_thread_main:142 - Run feeder thread cmd: quit
# 2024-03-06 14:40:37.680 | DEBUG    | pybuda.device:atexit_handler:919 - atexit handler called for (TTDevice 'tt_device_0',)
# 2024-03-06 14:40:37.681 | DEBUG    | pybuda.device:atexit_handler:923 - atexit handler completed
# 2024-03-06 14:40:37.575 | INFO     | Always          - finish_child_process called on pid 579546
# 2024-03-06 14:40:37.583 | INFO     | Always          - finish_child_process called on pid 579546
# 2024-03-06 14:40:37.603 | INFO     | Runtime         - Waiting for cluster completion
# 2024-03-06 14:40:37.604 | INFO     | PerfPostProcess - Writing the host postprocess report in /tmp/jonathan/8148d80c3efc/perf_results//host/device_alignment_th_1575208074_proc_579556.json
# 2024-03-06 14:40:37.654 | INFO     | Runtime         - Closed all devices successfully
# 2024-03-06 14:40:37.654 | INFO     | PerfCheck       - Starting performance check for host events
# 2024-03-06 14:40:37.654 | INFO     | PerfCheck       - Finished host performance check successfully
# 2024-03-06 14:40:37.654 | INFO     | Debuda          - Debug server ended on
# 2024-03-06 14:40:37.678 | INFO     | Always          - finish_child_process called on pid 579556
# 2024-03-06 14:40:37.681 | INFO     | Always          - finish_child_process called on pid 579556
# 2024-03-06 14:40:38.480 | INFO     | Always          - finish_child_process called on pid 577263
